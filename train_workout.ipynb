# %%
import spacy

# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.options.display.max_rows = 6
df = pd.read_csv("workout_buddy/train_data.csv")
df
# Out:
#                                                               Question  \
# 0        What are some effective exercises for building strong glutes?
# 1    How often should I change my workout routine for optimal results?
# 2                          What's the proper form for a barbell squat?
# ..                                                                 ...
# 227        Details on recent tricep overhead extensions: 12kg x 12 x 3
# 228                    Recent seated leg curls: 35kg x 15 x 3 details?
# 229                Outline recent dumbbell hammer curls: 10kg x 12 x 3
#
#      Category
# 0    EXERCISE
# 1    TRAINING
# 2    EXERCISE
# ..        ...
# 227    ACTION
# 228    ACTION
# 229    ACTION
#
# [230 rows x 2 columns]

# %%
from typing import Set, List, Tuple
import spacy

nlp = spacy.load("en_core_web_md")

for index, row in df.iterrows():
    print(row.Question)

# l = set(df.Category)
# print(l)
# Out:
# What are some effective exercises for building strong glutes?
# How often should I change my workout routine for optimal results?
# What's the proper form for a barbell squat?
# Can you recommend a high-intensity interval training (HIIT) workout?
# How do I prevent lower back pain during deadlifts?
# What's a good pre-workout meal for energy?
# What's the best way to increase my running endurance?
# Can you suggest a workout plan for fat loss?
# What's the recommended rest time between sets for muscle hypertrophy?
# What are some ways to stay motivated to exercise regularly?
# How do I target the inner chest during my chest workouts?
# What's the importance of warming up before a workout?
# Can you recommend exercises for improving flexibility?
# How do I avoid overtraining and burnout?
# What's the difference between free weights and machines for strength training?
# What's the best time of day to work out for maximum benefits?
# How can I incorporate more protein into my vegetarian diet for muscle building?
# What's a good routine for a beginner in weightlifting?
# How do I prevent muscle imbalances during my workouts?
# Can you suggest exercises to relieve tightness in the shoulders and neck?
# What's the role of recovery in muscle growth?
# How do I choose the right weight for my strength training exercises?
# Can you recommend a full-body workout for busy schedules?
# What's the importance of proper hydration during exercise?
# How can I improve my grip strength for deadlifts and pull-ups?
# What's the best way to track progress in my fitness journey?
# What are some effective exercises for targeting the hamstrings?
# How do I adjust my workout routine for home workouts without equipment?
# Can you suggest a routine for building lean muscle mass?
# What's the proper form for a plank exercise?
# How do I prevent muscle cramps during workouts?
# What's the role of carbohydrates in pre-workout nutrition?
# How can I improve my running speed and endurance?
# Can you recommend exercises for strengthening the core?
# What's the importance of a cooldown after a workout?
# How do I avoid common mistakes in the deadlift exercise?
# What's the best way to structure a workout for maximum fat burning?
# Can you suggest a stretching routine for flexibility improvement?
# How do I incorporate balance training into my workout routine?
# What's the importance of consistency in fitness training?
# Can you recommend exercises for building shoulder strength?
# How do I choose the right shoes for different types of workouts?
# What's the role of protein in muscle repair and growth?
# How do I target the outer thighs for a well-rounded leg workout?
# Can you suggest a workout routine for improving posture?
# What's the best approach to prevent muscle soreness after a tough workout?
# How can I vary my workouts to avoid boredom and plateaus?
# What's the proper form for a bicep curl exercise?
# How do I determine my one-rep max for strength training?
# Can you recommend exercises for building a strong stable core?
# What's the importance of a proper warm-up before cardio exercises?
# How do I modify exercises for home workouts with minimal equipment?
# What's the best way to recover from an intense workout?
# Can you suggest a routine for improving cardiovascular health?
# How do I prevent injuries during high-impact exercises?
# What's the role of sleep in muscle recovery and overall fitness?
# How can I incorporate mindfulness and relaxation into my fitness routine?
# What's the importance of cross-training in a fitness program?
# Can you recommend exercises for improving hip flexibility?
# How do I target the upper chest during my chest workouts?
# What's the best way to structure a workout for muscle endurance?
# Can you suggest a workout plan for someone with limited time?
# What's the proper form for a Romanian deadlift?
# How do I avoid overtraining while still pushing my limits?
# What's the role of nutrition in achieving fitness goals?
# How can I prevent muscle imbalances between my right and left sides?
# What's a good routine for increasing overall athletic performance?
# How do I progress in my strength training exercises over time?
# What's the best way to incorporate interval training into my routine?
# Can you recommend exercises for building strong calves?
# How do I choose the right workout intensity for my fitness level?
# What's the importance of a cooldown after cardiovascular exercises?
# How can I modify my workouts during pregnancy?
# What's a good routine for improving flexibility in the lower back?
# How do I prevent shoulder injuries during weightlifting?
# What's the role of supplements in a fitness and nutrition plan?
# Can you suggest a workout plan for enhancing overall mobility?
# What's the proper form for a push-up exercise?
# How do I adjust my workout routine for travel or limited equipment?
# What's the best way to target the triceps during arm workouts?
# Can you recommend exercises for building strong ankles?
# How do I prevent muscle stiffness after long periods of sitting?
# What's the importance of proper breathing during workouts?
# How can I modify exercises for joint pain or pre-existing injuries?
# What's a good routine for improving balance and coordination?
# How do I progress in my flexibility training over time?
# Can you suggest exercises for building strong lats?
# What's the best way to structure a workout for muscle hypertrophy?
# How do I avoid common mistakes in the bench press exercise?
# What's the role of core strength in overall fitness?
# Can you recommend a routine for improving agility and quickness?
# What was my total workout time during yesterday's session?
# What was my one-rep max on deadlifts last week?
# Log 35 x 12 x 3 for the flat bench press
# 3 sets of 10 reps of dumbell curls
# What was my total workout time during yesterday's session?
# What was my one-rep max on deadlifts last week?
# Log 35 x 12 x 3 for the flat bench press
# 3 sets of 10 reps of dumbbell curls
# Can you log my 5K run from yesterday?
# What was the weight progression in my squats during the last month?
# How did my bench press performance compare to my last workout?
# Log my 20-minute HIIT session today
# What was my average heart rate during yesterday's cardio session?
# How many calories did I burn in my workout yesterday?
# What's the recommended rest time between sets for my current workout plan?
# Can you suggest a new set of exercises for my next training split?
# Log my recent yoga session including duration and intensity
# What was the resistance level on the elliptical machine during my last session?
# Can you recommend variations for my bicep workouts?
# What's the best way to structure my workouts for a busy work schedule?
# Log my leg day routine including weights and reps
# How can I improve my deadlift form?
# What's the correct technique for a kettlebell swing?
# Log my recent spin class details including distance and resistance
# What's a good warm-up routine for my upcoming strength training session?
# Can you recommend exercises to target the obliques?
# How can I incorporate more flexibility exercises into my routine?
# What was my peak heart rate during yesterday's high-intensity interval training?
# Can you log my recent 5K run including time and pace?
# What's the best way to track my progress in bodyweight exercises?
# Log my recent Pilates session details including exercises and duration
# How can I optimize my nutrition for muscle recovery?
# What's the recommended progression for my current weightlifting program?
# Log my recent swim workout including laps and strokes
# How can I modify my training routine for a home workout with minimal equipment?
# What's the ideal tempo for my resistance training exercises?
# Log my recent CrossFit workout including WOD details
# What's the proper form for a Romanian deadlift?
# Can you recommend exercises for building strong shoulders?
# How can I prevent wrist pain during my weightlifting sessions?
# Log my recent trail run including terrain and elevation
# What's the best way to incorporate interval training into my cardio routine?
# Can you recommend exercises for improving my running stride?
# How do I adjust my workout routine during a busy travel schedule?
# Log my recent barre class details including exercises and reps
# What's the role of active recovery in my training program?
# Can you suggest a new set of bodyweight exercises for my routine?
# How do I target the lower abs during my core workouts?
# What's the importance of cross-training for overall fitness?
# Log my recent kickboxing session including techniques and intensity
# What's a good routine for improving hip mobility?
# How can I enhance my grip strength for better deadlift performance?
# What's the recommended frequency for my current strength training program?
# Log my recent rowing workout including distance and resistance
# Can you recommend exercises for building strong triceps?
# How do I avoid muscle imbalances in my upper body?
# What's the best way to structure a workout for muscle hypertrophy?
# Log my recent Zumba class including dance routines and intensity
# How can I improve my push-up endurance?
# What's the proper form for a plank exercise?
# Log my recent cycling session including distance and speed
# What's the role of deload weeks in my training program?
# Can you recommend exercises for improving my squat depth?
# How do I prevent shin splints during my running sessions?
# Log my recent circuit training session including exercises and rounds
# What's a good routine for improving ankle stability?
# How can I optimize my nutrition for endurance training?
# What's the proper form for a lateral raise exercise?
# Log my recent dance class including routines and intensity
# How do I adjust my workout routine for different phases of the menstrual cycle?
# Can you recommend exercises for building strong forearms?
# What's the importance of a proper cooldown after a high-intensity workout?
# Log my recent TRX training session including exercises and sets
# What's a good routine for enhancing overall flexibility?
# How can I incorporate more variety into my cardio workouts?
# What's the role of periodization in my strength training program?
# Log my recent kettlebell workout including exercises and weights
# What's the recommended rep range for my current muscle-building program?
# Can you recommend exercises for improving my posture?
# How do I avoid overtraining while still making progress?
# Log my recent rock climbing session including routes and difficulty
# What's a good routine for targeting the glutes?
# How can I improve my grip strength for better pull-up performance?
# What's the proper form for a barbell row exercise?
# Log my recent martial arts training session including techniques and intensity
# What's the importance of flexibility in preventing injuries during workouts?
# Can you recommend exercises for building strong hamstrings?
# How do I adjust my workout routine for seasonal changes?
# Log yesterday's workout: 40kg x 12 x 3 bench press
# Recent run: 5K in 25 mins details?
# Record dumbbell curls: 15 lbs 3 sets of 10
# Details on flat bench press: 50kg x 15 x 4
# Log recent swim: 1500m in 30 mins
# 5K run yesterday: Time and pace?
# Note 3 sets of 12 reps for leg press
# Capture squat session: 80kg x 10 x 3
# Log 30-minute HIIT: Exercises and intensity
# Recent deadlifts: 100kg x 5 x 3 details?
# Summarize lat pulldowns: 50kg x 10 x 3
# Dumbbell rows: 25 lbs 3 sets of 12
# Details on plank exercise: Held for 2 mins
# Record 20-minute elliptical: Resistance level 12
# Recent box jumps: 24 inches 3 sets of 10
# Note push-ups: 50 in 3 sets
# Detail 10K run: Completed in 55 mins
# Log kettlebell swings: 15kg x 20 x 4
# Capture recent leg curls: 40kg x 12 x 3
# Outline recent cable flyes: 15kg x 15 x 3
# Summarize 3 sets of 8 reps for overhead press at 25 pounds
# Record bench press: 60kg x 8 x 4
# Describe tricep dips: 3 sets of 12 reps
# Recent jump rope session: 500 jumps in 10 mins
# Log recent barbell row: 50kg x 10 x 3
# Summarize leg press: 80kg x 15 x 3
# Note reverse crunches: 3 sets of 15
# Capture face pulls: 20kg x 15 x 3
# Dumbbell curls: 12kg x 10 x 3 details?
# Details on 3 sets of 12 reps for tricep kickbacks: 8kg each
# Recent stair climbing workout: 30 floors in 15 mins
# Log recent box squats: 60kg x 10 x 3
# Capture recent Russian twists: 4 sets of 20 reps
# Outline recent leg extensions: 30kg x 12 x 3
# Summarize recent pull-ups: 3 sets of 8 reps
# Dumbbell pullovers: 15kg x 12 x 3 details?
# Record recent seated cable rows: 60kg x 12 x 3
# Note recent preacher curls: 12kg x 10 x 3
# Recent standing calf raises: 60kg x 20 x 3
# Log recent hanging leg raises: 3 sets of 12 reps
# Outline recent tricep rope pushdowns: 20kg x 15 x 3
# Describe recent side plank holds: 2 mins per side
# Details on recent medicine ball slams: 5kg ball 3 sets of 15
# Summarize recent leg raise variations: 3 sets of 12 reps each
# Record recent push press: 40kg x 10 x 3
# Recent dumbbell lateral raises: 8kg x 15 x 3 details?
# Log recent Bulgarian split squats: 20kg x 12 x 3
# Capture recent chin-ups: 3 sets of 10 reps
# Details on recent tricep overhead extensions: 12kg x 12 x 3
# Recent seated leg curls: 35kg x 15 x 3 details?
# Outline recent dumbbell hammer curls: 10kg x 12 x 3

# %%
from spacy.tokens import DocBin

def convert(df: pd.DataFrame, outfile:str):
    nlp = spacy.blank("en")
    db = DocBin()

    categories = list(set(df.Category))

    for _, row in df.iterrows():
        doc = nlp.make_doc(row.Question)
        doc.cats = {category: 0 for category in categories}
        doc.cats[row.Category] = 1
        db.add(doc)

    db.to_disk(outfile)



def make_docs(data: List[Tuple[str, str]], target_file: str, cats: Set[str]):
    nlp = spacy.load("en_core_web_md")
    docs = DocBin()
    # Use nlp.pipe to efficiently process a large number of text inputs,
    # the as_tuple arguments enables giving a list of tuples as input and
    # reuse it in the loop, here for the labels
    for doc, label in nlp.pipe(data, as_tuples=True):
        # Encode the labels (assign 1 the subreddit)
        for cat in cats:
            doc.cats[cat] = 1 if cat == label else 0
        docs.add(doc)
    docs.to_disk(target_file)
    return docs

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(df["Question"].values, df["Category"].values, test_size=0.3)
categories = list(set(df.Category))

make_docs(list(zip(X_train, y_train)), "train.spacy", cats=categories)
make_docs(list(zip(X_valid, y_valid)), "valid.spacy", cats=categories)

# %%
from spacy.cli.train import train as spacy_train
config_path = "spacy_textcat/config.cfg"
output_model_path = "output/workout_buddy"
spacy_train(
    config_path,
    output_path=output_model_path,
    overrides={
        "paths.train": "train.spacy",
        "paths.dev": "valid.spacy",
    },
)
# Out:
# ✔ Created output directory: output\workout_buddy
# ℹ Saving to output directory: output\workout_buddy
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTCAT  CATS_SCORE  SCORE
# ---  ------  ------------  ----------  ------
#   0       0          0.19        0.00    0.00
#  11     200         16.14       57.48    0.57
#  26     400          2.99       72.94    0.73
#  43     600          1.12       82.98    0.83
#  65     800          0.56       83.34    0.83
#  91    1000          0.32       82.89    0.83
# 123    1200          0.19       82.89    0.83
# 162    1400          0.13       84.15    0.84
# 209    1600          0.08       84.15    0.84
# 265    1800          0.06       84.92    0.85
# 332    2000          0.04       84.24    0.84
# 417    2200          0.03       83.75    0.84
# 517    2400          0.02       83.75    0.84
# 617    2600          0.01       83.75    0.84
# 717    2800          0.01       83.75    0.84
# 817    3000          0.01       83.75    0.84
# 917    3200          0.01       83.75    0.84
# 1017    3400          0.01       83.75    0.84
# ✔ Saved pipeline to output directory
# output\workout_buddy\model-last
